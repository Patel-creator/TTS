# %%
pip install phonemizer
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: phonemizer in c:\users\patel\appdata\roaming\python\python310\site-packages (3.3.0)
# Requirement already satisfied: segments in c:\users\patel\appdata\roaming\python\python310\site-packages (from phonemizer) (2.4.0)
# Requirement already satisfied: attrs>=18.1 in c:\users\patel\appdata\roaming\python\python310\site-packages (from phonemizer) (25.4.0)
# Requirement already satisfied: typing-extensions in c:\users\patel\appdata\roaming\python\python310\site-packages (from phonemizer) (4.15.0)
# Requirement already satisfied: joblib in c:\users\patel\appdata\roaming\python\python310\site-packages (from phonemizer) (1.5.3)
# Requirement already satisfied: dlinfo in c:\users\patel\appdata\roaming\python\python310\site-packages (from phonemizer) (2.0.0)
# Requirement already satisfied: regex in c:\users\patel\appdata\roaming\python\python310\site-packages (from segments->phonemizer) (2026.2.28)
# Requirement already satisfied: csvw>=1.5.6 in c:\users\patel\appdata\roaming\python\python310\site-packages (from segments->phonemizer) (3.7.0)
# Requirement already satisfied: uritemplate>=3.0.0 in c:\users\patel\appdata\roaming\python\python310\site-packages (from csvw>=1.5.6->segments->phonemizer) (4.2.0)
# Requirement already satisfied: babel in c:\users\patel\appdata\roaming\python\python310\site-packages (from csvw>=1.5.6->segments->phonemizer) (2.18.0)
# Requirement already satisfied: requests in c:\users\patel\appdata\roaming\python\python310\site-packages (from csvw>=1.5.6->segments->phonemizer) (2.32.5)
# Requirement already satisfied: python-dateutil in c:\users\patel\appdata\roaming\python\python310\site-packages (from csvw>=1.5.6->segments->phonemizer) (2.9.0.post0)
# Requirement already satisfied: language-tags in c:\users\patel\appdata\roaming\python\python310\site-packages (from csvw>=1.5.6->segments->phonemizer) (1.2.0)
# Requirement already satisfied: jsonschema in c:\users\patel\appdata\roaming\python\python310\site-packages (from csvw>=1.5.6->segments->phonemizer) (4.26.0)
# Requirement already satisfied: isodate in c:\users\patel\appdata\roaming\python\python310\site-packages (from csvw>=1.5.6->segments->phonemizer) (0.7.2)
# Requirement already satisfied: rfc3986<2 in c:\users\patel\appdata\roaming\python\python310\site-packages (from csvw>=1.5.6->segments->phonemizer) (1.5.0)
# Requirement already satisfied: rdflib in c:\users\patel\appdata\roaming\python\python310\site-packages (from csvw>=1.5.6->segments->phonemizer) (7.6.0)
# Requirement already satisfied: termcolor in c:\users\patel\appdata\roaming\python\python310\site-packages (from csvw>=1.5.6->segments->phonemizer) (3.3.0)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\patel\appdata\roaming\python\python310\site-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer) (0.37.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\patel\appdata\roaming\python\python310\site-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer) (2025.9.1)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\patel\appdata\roaming\python\python310\site-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer) (0.30.0)
# Requirement already satisfied: six>=1.5 in c:\users\patel\appdata\roaming\python\python310\site-packages (from python-dateutil->csvw>=1.5.6->segments->phonemizer) (1.17.0)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in c:\users\patel\appdata\roaming\python\python310\site-packages (from rdflib->csvw>=1.5.6->segments->phonemizer) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\patel\appdata\roaming\python\python310\site-packages (from requests->csvw>=1.5.6->segments->phonemizer) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\patel\appdata\roaming\python\python310\site-packages (from requests->csvw>=1.5.6->segments->phonemizer) (2026.2.25)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\patel\appdata\roaming\python\python310\site-packages (from requests->csvw>=1.5.6->segments->phonemizer) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\patel\appdata\roaming\python\python310\site-packages (from requests->csvw>=1.5.6->segments->phonemizer) (3.11)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install espeakng
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: espeakng in c:\users\patel\appdata\roaming\python\python310\site-packages (1.0.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
apt-get install -y espeak-ng
# Out:
#   Cell In[8], line 1
#     apt-get install -y espeak-ng
#             ^
# SyntaxError: invalid syntax

# %%
text = "I have 2 apples"

text = text.lower()

print(text)
# Out:
# i have 2 apples

# %%
text = "hello"

tokens = [ord(c) for c in text]

print(tokens)
# Out:
# [104, 101, 108, 108, 111]

# %%
import os
from phonemizer import phonemize
from phonemizer.backend.espeak.wrapper import EspeakWrapper

# Set the path to the espeak-ng dll file
# Adjust this path if you installed eSpeak-NG in a different folder


text = "hello how are you"

phonemes = phonemize(text, language='en-us')

print(phonemes)
_espeak_library = r"C:\Program Files\eSpeak NG\libespeak-ng.dll"
EspeakWrapper.set_library(_espeak_library)
# Out:
# həloʊ haʊ ɑːɹ juː

# %%
p = phonemes

tokens = [ord(c) for c in p]

print(tokens)
# Out:
# [104, 601, 108, 111, 650, 32, 104, 97, 650, 32, 593, 720, 633, 32, 106, 117, 720, 32]
